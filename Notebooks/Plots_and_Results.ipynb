# %%
import import_ipynb
import matplotlib.pyplot as plt
import Models_Notebook
from Models_Notebook import model, preds_all, LR_error2, dnn_error2, knn_error2
# Out:
# importing Jupyter notebook from Models_Notebook.ipynb
# Using TensorFlow backend.

# %% [markdown]
# Plots:

# %%
plt.figure(figsize=(12,8))
plt.plot(preds_all['Actual'].values, color='salmon', label='Actual')
plt.plot(preds_all['KNN_preds'].values, color='yellowgreen', label='KNN_preds')
plt.title("Actual vs Linear Regression Predictions", fontsize = 15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(preds_all['Actual'].values, color='salmon', label='Actual')
plt.plot(preds_all['LR_preds'].values, color='skyblue', label='KNN_preds')
plt.title("Actual vs KNN Predictions", fontsize = 15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(preds_all['Actual'].values, color='salmon', label='Actual')
plt.plot(preds_all['DNN_preds'].values, color='seagreen', label='KNN_preds')
plt.title("Actual vs DNN Predictions", fontsize = 15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# Report Error:

# %%
print("The RMSE for the Linear Regression Model is {}, for the DNN model is {} and for the KNN model is {}.".format(LR_error2, dnn_error2, knn_error2))
# Out:
# The RMSE for the Linear Regression Model is 105.66, for the DNN model is 95.05 and for the KNN model is 143.74.
